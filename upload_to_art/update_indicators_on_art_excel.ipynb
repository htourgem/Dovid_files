# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

pd.set_option("display.max_columns",100) # don’t put … instead of multi columns
pd.set_option('expand_frame_repr',False) # for not wrapping columns if you have many
pd.set_option("display.max_rows",10)
pd.set_option('display.min_rows', 10)
pd.set_option('display.max_colwidth',100)

tqdm.pandas()

import sys
sys.path.append('/nfs/iil/disks/hip_ana_sim_01/dgottesm/analysis_and_tools/analysisPP/brk_gen1/Automation/PostProcess')
sys.path.append(r'/mnt/c/Users/lisrael1/OneDrive - Intel Corporation/Desktop/PP/brk_gen1/Automation/PostProcess')
from imp import reload 
import sine_analysis
from sine_analysis import run
# Out:
# /nfs/iil/disks/hdk_ws/ckt/lisrael1/lior_dir/virtual_env/env/lib/python3.6/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
you should use ipywidgets.FileUpload instead 
df=pd.read_excel('/nfs/iil/disks/ams_regruns/dkl/users/lisrael1/msv/temp_del/aaa/lisrael1_2020-12-28_15-37-38.xlsx', header=[1])
# df=pd.read_excel('/nfs/iil/disks/ams_regruns/dkl/users/lisrael1/msv/temp_del/aaa/lisrael1_2020-12-28_15-37-38.xlsx', header=[1])
if 0:
    boring_columns=df.nunique().to_frame('number_of_unique').query('number_of_unique<2').index.tolist()
    df=df.drop(columns=boring_columns)

# %%
df.shape
# Out:
# (4111, 112)

# %%
out=df.progress_apply(lambda r: run.run(data=r.to_dict()), axis='columns')
# Out:
#   0%|          | 0/4111 [00:00<?, ?it/s]
# we dont have floating values at the input. treating input as codes
# got raw data as list. adding sampling timing and sar numbers 0.031 sec
# got 64000 input samples
# zero crossing - you have 64000 samples, 551 full cycles. freq GHz = 0.48275862068965525, so you have cycle every 116.1524500907441 samples, every 2.071428571428571 ns
# calculating data histogram 0.503 sec
# finding fft basic properties 0.035 sec
# freq estimation by FFT is at the lowest 3 bins of the FFT, and it might be problem at the ADC like offsets or something, so taking highest from above 3 bins
# running curve fit 0.026 sec
# given (fft or zero crossing) freq GHz estimation is 0.483. cf look for freq between 0.48212499999999997 and 0.483875
# calculating errors by best fit 1.639 sec
# calculating extra analysis on curve fit - SNDR (SINAD) and enob 0.016 sec
# finding fft properties like harmonies / offset / gain spurs 0.003 sec
# doing fft per oct/sar 0.09 sec
# ...
